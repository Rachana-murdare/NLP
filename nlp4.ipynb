# %%
pip install --upgrade nltk
# Out:
# Requirement already satisfied: nltk in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (3.4)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 430.4 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 430.4 kB/s eta 0:00:03
#    ------------- -------------------------- 0.5/1.5 MB 430.4 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 385.8 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.5 MB 385.8 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.5 MB 385.8 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.5 MB 385.8 kB/s eta 0:00:02
#    --------------------------- ------------ 1.0/1.5 MB 387.2 kB/s eta 0:00:02
#    --------------------------- ------------ 1.0/1.5 MB 387.2 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 399.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 399.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 399.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 395.8 kB/s eta 0:00:00
# Downloading regex-2024.9.11-cp312-cp312-win_amd64.whl (273 kB)
# Installing collected packages: regex, nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.4
#     Uninstalling nltk-3.4:
#       Successfully uninstalled nltk-3.4
# Successfully installed nltk-3.9.1 regex-2024.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.lm.preprocessing import pad_both_ends, flatten

# %%
from nltk.util import pad_sequence
from nltk.util import bigrams
from nltk.util import ngrams
from nltk.util import everygrams
from nltk.lm.preprocessing import pad_both_ends
from nltk.lm.preprocessing import flatten

# %%
text = [['a', 'b', 'c'], ['a', 'c', 'd', 'c', 'e', 'f']]
list(bigrams(text[0]))
# Out:
# [('a', 'b'), ('b', 'c')]

# %%
list(ngrams(text[1], n=3))
# Out:
# [('a', 'c', 'd'), ('c', 'd', 'c'), ('d', 'c', 'e'), ('c', 'e', 'f')]

# %%
# !pip install -U pip
# !pip install -U dill
# !pip install -U nltk==3.4
# Out:
# Requirement already satisfied: pip in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (24.2)
# Requirement already satisfied: dill in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (0.3.9)
# Collecting nltk==3.4
#   Using cached nltk-3.4-py3-none-any.whl
# Requirement already satisfied: six in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from nltk==3.4) (1.16.0)
# Requirement already satisfied: singledispatch in c:\users\rachana\appdata\local\programs\python\python312\lib\site-packages (from nltk==3.4) (4.1.0)
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
# Successfully installed nltk-3.4

# %%
from nltk.util import pad_sequence
list(pad_sequence(text[0],
                  pad_left=True, left_pad_symbol="<s>",
                  pad_right=True, right_pad_symbol="</s>",
                  n=2)) # The n order of n-grams, if it's 2-grams, you pad once, 3-grams pad twice, etc.
# Out:
# ['<s>', 'T', '</s>']

# %%
import os
import requests
import io #codecs


# Text version of https://kilgarriff.co.uk/Publications/2005-K-lineer.pdf
if os.path.isfile('language-never-random.txt'):
    with io.open('language-never-random.txt', encoding='utf8') as fin:
        text = fin.read()
else:
    url = "https://gist.githubusercontent.com/alvations/53b01e4076573fea47c6057120bb017a/raw/b01ff96a5f76848450e648f35da6497ca9454e4a/language-never-random.txt"
    text = requests.get(url).content.decode('utf8')
    with io.open('language-never-random.txt', 'w', encoding='utf8') as fout:
        fout.write(text)

# %%
padded_sent = list(pad_sequence(text[0], pad_left=True, left_pad_symbol="<s>", 
                                pad_right=True, right_pad_symbol="</s>", n=2))
list(ngrams(padded_sent, n=2))
# Out:
# [('<s>', ' '), (' ', '</s>')]

# %%
padded_sent = list(pad_sequence(text[0], pad_left=True, left_pad_symbol="<s>", 
                                pad_right=True, right_pad_symbol="</s>", n=3))
list(ngrams(padded_sent, n=3))
# Out:
# [('<s>', '<s>', ' '), ('<s>', ' ', '</s>'), (' ', '</s>', '</s>')]

# %%
from nltk.lm.preprocessing import pad_both_ends
list(pad_both_ends(text[0], n=2))
# Out:
# ['<s>', ' ', '</s>']

# %%
from nltk.util import everygrams
padded_bigrams = list(pad_both_ends(text[0], n=2))
list(everygrams(padded_bigrams, max_len=2))
# Out:
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]

# %%
from nltk.lm.preprocessing import flatten
list(flatten(pad_both_ends(sent, n=2) for sent in text))
# Out:
# ['<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'D',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'M',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'K',
#  '</s>',
#  '<s>',
#  'I',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'G',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'R',
#  '</s>',
#  '<s>',
#  'R',
#  '</s>',
#  '<s>',
#  'I',
#  '</s>',
#  '<s>',
#  'F',
#  '</s>',
#  '<s>',
#  'F',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'b',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  '-',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  '.',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'S',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  '.',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'H',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ...]

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
train, vocab = padded_everygram_pipeline(2, text)

# %%
training_ngrams, padded_sentences = padded_everygram_pipeline(2, text)
for ngramlize_sent in training_ngrams:
    print(list(ngramlize_sent))
    print()
print('#############')
list(padded_sentences)
# Out:
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'L'), ('L',), ('L', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'A'), ('A',), ('A', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'D'), ('D',), ('D', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'A'), ('A',), ('A', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'M'), ('M',), ('M', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'K'), ('K',), ('K', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'I'), ('I',), ('I', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'L'), ('L',), ('L', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'G'), ('G',), ('G', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'A'), ('A',), ('A', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'R'), ('R',), ('R', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'R'), ('R',), ('R', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'I'), ('I',), ('I', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'F'), ('F',), ('F', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'F'), ('F',), ('F', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'A'), ('A',), ('A', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'L'), ('L',), ('L', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '-'), ('-',), ('-', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'S'), ('S',), ('S', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'H'), ('H',), ('H', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'k'), ('k',), ('k', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '-'), ('-',), ('-', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'M'), ('M',), ('M', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '('), ('(',), ('(', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ')'), (')',), (')', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'I'), ('I',), ('I', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'q'), ('q',), ('q', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '-'), ('-',), ('-', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '-'), ('-',), ('-', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '-'), ('-',), ('-', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'W'), ('W',), ('W', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'x'), ('x',), ('x', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'y'), ('y',), ('y', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'q'), ('q',), ('q', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# ...
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'm'), ('m',), ('m', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'p'), ('p',), ('p', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ':'), (':',), (':', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'O'), ('O',), ('O', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'r'), ('r',), ('r', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'b'), ('b',), ('b', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'l'), ('l',), ('l', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'w'), ('w',), ('w', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'h'), ('h',), ('h', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'q'), ('q',), ('q', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'v'), ('v',), ('v', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'd'), ('d',), ('d', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'F'), ('F',), ('F', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'c'), ('c',), ('c', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 't'), ('t',), ('t', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'i'), ('i',), ('i', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 's'), ('s',), ('s', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'o'), ('o',), ('o', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'f'), ('f',), ('f', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'L'), ('L',), ('L', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'n'), ('n',), ('n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'u'), ('u',), ('u', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'a'), ('a',), ('a', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'g'), ('g',), ('g', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', 'e'), ('e',), ('e', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '2'), ('2',), ('2', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '('), ('(',), ('(', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '1'), ('1',), ('1', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ')'), (')',), (')', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ','), (',',), (',', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', ' '), (' ',), (' ', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '2'), ('2',), ('2', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '3'), ('3',), ('3', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '⫺'), ('⫺',), ('⫺', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '5'), ('5',), ('5', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '5'), ('5',), ('5', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '.'), ('.',), ('.', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\n'), ('\n',), ('\n', '</s>'), ('</s>',)]
#
# [('<s>',), ('<s>', '\x0c'), ('\x0c',), ('\x0c', '</s>'), ('</s>',)]
#
# #############
# ['<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'D',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'M',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'K',
#  '</s>',
#  '<s>',
#  'I',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'G',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'R',
#  '</s>',
#  '<s>',
#  'R',
#  '</s>',
#  '<s>',
#  'I',
#  '</s>',
#  '<s>',
#  'F',
#  '</s>',
#  '<s>',
#  'F',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'A',
#  '</s>',
#  '<s>',
#  'b',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'L',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'v',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  '-',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  '.',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'S',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'g',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'u',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  'l',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'y',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  '\n',
#  '</s>',
#  '<s>',
#  'p',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  'i',
#  '</s>',
#  '<s>',
#  't',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'r',
#  '</s>',
#  '<s>',
#  'a',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'd',
#  '</s>',
#  '<s>',
#  'o',
#  '</s>',
#  '<s>',
#  'm',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  's',
#  '</s>',
#  '<s>',
#  '.',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'H',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  'c',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ',',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'h',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  'n',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  'w',
#  '</s>',
#  '<s>',
#  'e',
#  '</s>',
#  '<s>',
#  ' ',
#  '</s>',
#  '<s>',
#  ...]

# %%
try: # Use the default NLTK tokenizer.
    from nltk import word_tokenize, sent_tokenize 
    # Testing whether it works. 
    # Sometimes it doesn't work on some machines because of setup issues.
    word_tokenize(sent_tokenize("This is a foobar sentence. Yes it is.")[0])
except: # Use a naive sentence tokenizer and toktok.
    import re
    from nltk.tokenize import ToktokTokenizer
    # See https://stackoverflow.com/a/25736515/610569
    sent_tokenize = lambda x: re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', x)
    # Use the toktok tokenizer that requires no dependencies.
    toktok = ToktokTokenizer()
    word_tokenize = word_tokenize = toktok.tokenize

# %%
import os
import requests
import io #codecs


# Text version of https://kilgarriff.co.uk/Publications/2005-K-lineer.pdf
if os.path.isfile('language-never-random.txt'):
    with io.open('language-never-random.txt', encoding='utf8') as fin:
        text = fin.read()
else:
    url = "https://gist.githubusercontent.com/alvations/53b01e4076573fea47c6057120bb017a/raw/b01ff96a5f76848450e648f35da6497ca9454e4a/language-never-random.txt"
    text = requests.get(url).content.decode('utf8')
    with io.open('language-never-random.txt', 'w', encoding='utf8') as fout:
        fout.write(text)

# %%
tokenized_text = [list(map(str.lower, word_tokenize(sent))) 
                  for sent in sent_tokenize(text)]

# %%
tokenized_text[0]
# Out:
# ['language',
#  'is',
#  'never',
#  ',',
#  'ever',
#  ',',
#  'ever',
#  ',',
#  'random',
#  'adam',
#  'kilgarriff',
#  'abstract',
#  'language',
#  'users',
#  'never',
#  'choose',
#  'words',
#  'randomly',
#  ',',
#  'and',
#  'language',
#  'is',
#  'essentially',
#  'non-random',
#  '.']
